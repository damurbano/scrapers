# %%
from mercadolibre import main

article = main("arete")
 # Imprime el artículo
# Out:
# Categorías
# Nombre de la categoria:
# Categorías
# ********************
# Joyas y Bijouterie CANTIDAD: 212
# ********************
# Total de resultados: 212
# Scraping página 1: https://listado.mercadolibre.com.ar/joyas-relojes/joyas-bijouterie/arete_NoIndex_True#applied_filter_id%3Dcategory%26applied_filter_name%3DCategor%C3%ADas%26applied_filter_order%3D3%26applied_value_id%3DMLA1431%26applied_value_name%3DJoyas+y+Bijouterie%26applied_value_order%3D3%26applied_value_results%3D212%26is_custom%3Dfalse
# 50 PRODUCTOS ENCONTRADOS
#
# 49 PRODUCTOS ÚNICOS
# Producto: Anzuelo Para Aro X 500 Pares De Acero Quirúrgico, Simples, Precio: $22,958
# Producto: Anzuelo Para Aro X 250 Pares De Acero Quirúrgico, Simples, Precio: $24,300
# Producto: Aretes Kamado Tanjiro Demon Slayer Kimetsu No Yaiba 3 Pares Color Negro, Precio: $16,000
# Producto: Aretes De Diamante Zircon Para Hombre Y Mujer 6 Mm Con Caja, Precio: $22,174
# ...
